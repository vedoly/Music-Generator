# %%
import os
import errno
import py_midicsv
import numpy as np
import pandas as pd
import mido
from music21 import *
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-47-e74b943efb2f> in <module>
#       8 from mido import MidiFile
#       9
# ---> 10 mid = MidiFile('Dragon_Ball_GT_Brass_quintet.mid')
#
# C:\ProgramData\Anaconda3\lib\site-packages\mido\midifiles\midifiles.py in __init__(self, filename, file, type, ticks_per_beat, charset, debug)
#     294         elif self.filename is not None:
#     295             with io.open(filename, 'rb') as file:
# --> 296                 self._load(file)
#     297
#     298     def add_track(self, name=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\mido\midifiles\midifiles.py in _load(self, infile)
#     318             (self.type,
#     319              num_tracks,
# --> 320              self.ticks_per_beat) = read_file_header(infile)
#     321
#     322             if self.debug:
#
# ...

# %%
mid = MidiFile('Dragon_Ball_GT_Brass_quintet.mid', clip=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-4ae71df888cc> in <module>
# ----> 1 mid = MidiFile('Dragon_Ball_GT_Brass_quintet.mid', clip=True)
#
# NameError: name 'MidiFile' is not defined

# %%
import os
import py_midicsv
for filename in os.listdir('data'):
    print(filename)
    csv = py_midicsv.midi_to_csv(filename)
    for line in csv:
        print(line)
    break
    Ans=[]
    for k in csv:
        L=k.strip().split(", ")
        Ans.append(L)
    df = pd.DataFrame(Ans)
    df.to_csv("data2/"+filename+".csv")
# Out:
# Country_Roads_-_John_Denver_Brass_Quintet.mid
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-7e561458d57e> in <module>
#       3 for filename in os.listdir('data'):
#       4     print(filename)
# ----> 5     csv = py_midicsv.midi_to_csv(filename)
#       6     for line in csv:
#       7         print(line)
#
# C:\ProgramData\Anaconda3\lib\site-packages\py_midicsv\midicsv.py in parse(file)
#      20     """
#      21     csv_file = []
# ---> 22     pattern = read_midifile(file)
#      23     csv_file.append("0, 0, Header, {}, {}, {}\n".format(pattern.format,
#      24                                                         len(pattern),
#
# C:\ProgramData\Anaconda3\lib\site-packages\py_midicsv\midi\fileio.py in read_midifile(midifile)
#     223     if type(midifile) in (str, bytes):
#     224         with open(midifile, "rb") as inp:
# ...

# %%
s = converter.parse('Take_on_me_Brass_Quintet.mxl')
test=s.measures(1, 10)
test.plot('horizontalbar')
s.analyze('key')
# Out:
# <music21.key.Key of f# minor>

# %%
piece = converter.parse('Take_on_me_Brass_Quintet.mxl')
for part in piece.parts:
   
    x=part.notesAndRests
    
print(x)
# Out:
# <music21.stream.iterator.StreamIterator for Part:Tuba @:0>

# %%
midd = mido.MidiFile('Dragon_Ball_GT_Brass_quintet.mid')
for msg in midd.play():
    print(msg)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-45-7c8cc1ad6d4a> in <module>
# ----> 1 midd = mido.MidiFile('Dragon_Ball_GT_Brass_quintet.mid')
#       2 for msg in midd.play():
#       3     print(msg)
#
# C:\ProgramData\Anaconda3\lib\site-packages\mido\midifiles\midifiles.py in __init__(self, filename, file, type, ticks_per_beat, charset, debug)
#     294         elif self.filename is not None:
#     295             with io.open(filename, 'rb') as file:
# --> 296                 self._load(file)
#     297
#     298     def add_track(self, name=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\mido\midifiles\midifiles.py in _load(self, infile)
#     318             (self.type,
#     319              num_tracks,
# --> 320              self.ticks_per_beat) = read_file_header(infile)
#     321
#     322             if self.debug:
#
# ...
