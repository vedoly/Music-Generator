# %%
import py_midicsv
import numpy as np
import pandas as pd
import os
file = open("/data/1.mid")
csv_a = py_midicsv.midi_to_csv("/data/1.mid")

Ans=[]
Ans2=[]

for k in csv_a:
    L=k.strip().split(", ")
 
#     if L[2] == "Note_on_c":
#         #L[2] = 1
#         Ans.append(L)
#     elif L[2] == "Note_off_c":
#         #L[2] = 0
    Ans.append(L)

df=Ans
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-e8cf438a3aa6> in <module>
#       3 import pandas as pd
#       4 import os
# ----> 5 file = open("/data/1.mid")
#       6 csv_a = py_midicsv.midi_to_csv("/data/1.mid")
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/1.mid'

# %%
df = pd.DataFrame(Ans)
df.to_csv('Data/aaaaaa.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-2-9c52ca8892dc> in <module>
#       1 df = pd.DataFrame(Ans)
# ----> 2 df.to_csv('aaaaaaa.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ...

# %%
dc = df.iloc[30:]
dc[4]
# Out:
# 30        81
# 31        54
# 32        81
# 33        54
# 34        80
#         ...
# 1627      69
# 1628      54
# 1629      69
# 1630    None
# 1631    None
# Name: 4, Length: 1602, dtype: object

# %%
for k in csv_c:
    L=k.strip().split(", ")
    if L[2] == "Note_on_c":
        L[2] = 1
    
        if int(L[-1]) > 0:
            print(L[-1])
            Ans2.append(L)

out1 = 0
out2 = 0
n1 = 0
n2 =0
for k in Ans2:
    #print(type(k[0]) )
    if k[0] == 1:
        out1 += int(k[4])
        n1 += 1
    else:
        out2 +=int(k[4])
        n2 += 1
# Out:
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# ...

# %%
from mido import Message, MidiFile, MidiTrack

mid = MidiFile()
track = MidiTrack()
mid.tracks.append(track)
print(mid.tracks[0])
track.append(Message('program_change', program=12, time=0))
PREV = 0
for k in mA:
    print(k[0], k[1])
    track.append(Message('note_on', note=int(k[0]), velocity=127, time = int(k[1]) - PREV ) )
    PREV = int(k[1])
#track.append(Message('note_off', note=64, velocity=127, time=32))

mid.save('new_songX.mid')
c =  py_midicsv.midi_to_csv('new_songX.mid' )

c
# Out:
# <midi track '' 0 messages>
# 81 0
# 54 0
# 81 128
# 54 128
# 80 128
# 61 128
# 80 256
# 61 256
# 81 256
# 66 256
# 81 384
# 80 384
# 80 512
# 66 512
# 81 512
# 50 512
# 81 640
# 50 640
# 76 640
# 57 640
# 76 768
# 57 768
# 81 768
# 64 768
# 81 896
# 74 896
# 74 1664
# 69 1664
# 69 1728
# 73 1728
# 73 1792
# 64 1792
# 81 1792
# 54 1792
# 81 1920
# 54 1920
# 80 1920
# 61 1920
# 80 2048
# 61 2048
# 81 2048
# 66 2048
# 81 2176
# 80 2176
# 80 2304
# 66 2304
# 81 2304
# 50 2304
# 81 2432
# 50 2432
# 76 2432
# 57 2432
# 76 2560
# 57 2560
# 81 2560
# 64 2560
# 81 2688
# 74 2688
# 74 3456
# 69 3456
# 69 3520
# 73 3520
# 73 3584
# 64 3584
# 81 3584
# 54 3584
# 81 3712
# 54 3712
# 80 3712
# 61 3712
# 80 3776
# 81 3776
# 61 3840
# 66 3840
# 81 3904
# 69 3904
# 69 3968
# 80 3968
# 80 4032
# 81 4032
# 66 4096
# 50 4096
# 81 4160
# 69 4160
# 69 4224
# 50 4224
# 76 4224
# 57 4224
# 76 4288
# 81 4288
# 57 4352
# 64 4352
# 81 4416
# 69 4416
# 69 4480
# 64 4480
# 74 4480
# 50 4480
# 74 4544
# 69 4544
# ...

# %%
csv_c = py_midicsv.midi_to_csv("new_song5.mid")
csv_c
# Out:
# ['0, 0, Header, 1, 1, 480\n',
#  '1, 0, Start_track\n',
#  '1, 0, Program_c, 0, 12\n',
#  '1, 1000, Note_on_c, 0, 64, 127\n',
#  '1, 1000, Note_on_c, 0, 64, 127\n',
#  '1, 1000, Note_on_c, 0, 81, 127\n',
#  '1, 2000, Note_on_c, 0, 20, 127\n',
#  '1, 3000, Note_on_c, 0, 42, 127\n',
#  '1, 4000, Note_on_c, 0, 63, 127\n',
#  '1, 4000, End_track\n',
#  '0, 0, End_of_file']

# %%
def minimize(A):
    G=[]
    for k in A:
        L=[]
        L.append(int(k[4]) )
        L.append(int(k[1])-7680) 
       
        G.append(L)
    return G

# %%
mA =minimize(Ans2)
mA = mA[1:]
mA
# Out:
# [[78, 0],
#  [76, 960],
#  [74, 1920],
#  [73, 2880],
#  [71, 3840],
#  [69, 4800],
#  [71, 5760],
#  [73, 6720],
#  [69, 7680],
#  [74, 7680],
#  [78, 7680],
#  [69, 8640],
#  [73, 8640],
#  [76, 8640],
#  [66, 9600],
#  [71, 9600],
#  [74, 9600],
#  [66, 10560],
#  [69, 10560],
#  [73, 10560],
#  [62, 11520],
#  [67, 11520],
#  [71, 11520],
#  [62, 12480],
#  [66, 12480],
#  [69, 12480],
#  [62, 13440],
#  [67, 13440],
#  [71, 13440],
#  [64, 14400],
#  [69, 14400],
#  [73, 14400],
#  [74, 15360],
#  [78, 15840],
#  [81, 16320],
#  [79, 16800],
#  [78, 17280],
#  [74, 17760],
#  [78, 18240],
#  [76, 18960],
#  [74, 19200],
#  [71, 19680],
#  [74, 20160],
#  [78, 20640],
#  [79, 21120],
#  [83, 21600],
#  [81, 22080],
#  [79, 22800],
#  [74, 23040],
#  [78, 23040],
#  [78, 23520],
#  [76, 24000],
#  [81, 24000],
#  [79, 24480],
#  [74, 24960],
#  [78, 24960],
#  [74, 25440],
#  [73, 25920],
#  [78, 25920],
#  [76, 26640],
#  [71, 26880],
#  [74, 26880],
#  [71, 27360],
# ...

# %%
csv_a
# Out:
# ['0, 0, Header, 1, 2, 256\n',
#  '1, 0, Start_track\n',
#  '1, 0, Time_signature, 4, 2, 24, 8\n',
#  '1, 0, Key_signature, 3, "major"\n',
#  '1, 0, Tempo, 923075\n',
#  '1, 1024, Tempo, 923074\n',
#  '1, 1024, Time_signature, 3, 2, 24, 8\n',
#  '1, 1792, Tempo, 923073\n',
#  '1, 1792, Time_signature, 4, 2, 24, 8\n',
#  '1, 2816, Tempo, 923073\n',
#  '1, 2816, Time_signature, 3, 2, 24, 8\n',
#  '1, 3584, Tempo, 923073\n',
#  '1, 3584, Time_signature, 4, 2, 24, 8\n',
#  '1, 18944, Tempo, 923073\n',
#  '1, 18944, Time_signature, 5, 2, 24, 8\n',
#  '1, 19712, Tempo, 1384608\n',
#  '1, 19840, Tempo, 2076913\n',
#  '1, 20096, Tempo, 1384608\n',
#  '1, 20224, Tempo, 923073\n',
#  '1, 20224, Time_signature, 4, 2, 24, 8\n',
#  '1, 44032, Tempo, 1384608\n',
#  '1, 44288, Tempo, 2076913\n',
#  '1, 44544, Tempo, 923073\n',
#  '1, 44800, Tempo, 1384608\n',
#  '1, 44801, End_track\n',
#  '2, 0, Start_track\n',
#  '2, 0, Control_c, 0, 0, 0\n',
#  '2, 0, Control_c, 0, 32, 0\n',
# ...

# %%
csv_c
# Out:
# ['0, 0, Header, 1, 2, 480\n',
#  '1, 0, Start_track\n',
#  '1, 0, Time_signature, 4, 2, 24, 8\n',
#  '1, 0, Key_signature, 1, "major"\n',
#  '1, 0, Tempo, 666667\n',
#  '1, 0, Control_c, 0, 121, 0\n',
#  '1, 0, Program_c, 0, 0\n',
#  '1, 0, Control_c, 0, 7, 100\n',
#  '1, 0, Control_c, 0, 10, 64\n',
#  '1, 0, Control_c, 0, 91, 0\n',
#  '1, 0, Control_c, 0, 93, 0\n',
#  '1, 0, MIDI_port, 0\n',
#  '1, 0, Note_on_c, 0, 67, 80\n',
#  '1, 455, Note_on_c, 0, 67, 0\n',
#  '1, 480, Note_on_c, 0, 67, 80\n',
#  '1, 935, Note_on_c, 0, 67, 0\n',
#  '1, 960, Note_on_c, 0, 67, 80\n',
#  '1, 1415, Note_on_c, 0, 67, 0\n',
#  '1, 1440, Note_on_c, 0, 71, 80\n',
#  '1, 1895, Note_on_c, 0, 71, 0\n',
#  '1, 1920, Note_on_c, 0, 76, 80\n',
#  '1, 2375, Note_on_c, 0, 76, 0\n',
#  '1, 2400, Note_on_c, 0, 76, 80\n',
#  '1, 2855, Note_on_c, 0, 76, 0\n',
#  '1, 2880, Note_on_c, 0, 76, 80\n',
#  '1, 3335, Note_on_c, 0, 76, 0\n',
#  '1, 3360, Note_on_c, 0, 74, 80\n',
#  '1, 3815, Note_on_c, 0, 74, 0\n',
# ...

# %%
from midiutil import MIDIFile

degrees  = [60, 62, 64, 65, 67, 69, 71, 72]  # MIDI note number
track    = 0
channel  = 0
time     = 0    # In beats
duration = 0.5    # In beats
tempo    = 1  # In BPM
volume   = 100  # 0-127, as per the MIDI standard

MyMIDI = MIDIFile(1)  # One track, defaults to format 1 (tempo track is created
                      # automatically)
MyMIDI.addTempo(track, time, tempo)

for k in L:
 
    MyMIDI.addNote(track, channel, int(k[0]), float(k[1]), 0.002, volume)

with open("major-scale7778.mid", "wb") as output_file:
    MyMIDI.writeFile(output_file)
print("A")
# Out:
# A

# %%
f = open('demofile2.txt', "r")
lines = list(f)
L=[]
for k in lines:
    
    x=k.strip().split()
    if (len(x) < 2 ):
        continue
    if( int(x[0])<0 or int(x[0]) >255):
        continue
    if int(x[1]) < 122880:
        continue
    L.append ( ( int(x[0] ), (int(x[1])-122880 ) /480 ) )
L
# Out:
# [(101, 187.25208333333333),
#  (39, 187.25625),
#  (99, 187.2625),
#  (44, 187.2625),
#  (90, 187.27083333333334),
#  (86, 187.27083333333334),
#  (83, 187.27083333333334),
#  (79, 187.27083333333334),
#  (75, 187.27083333333334),
#  (72, 187.27083333333334),
#  (69, 187.27083333333334),
#  (66, 187.27083333333334),
#  (62, 187.27083333333334),
#  (59, 187.27083333333334),
#  (55, 187.27083333333334),
#  (51, 187.27083333333334),
#  (73, 187.27083333333334),
#  (70, 187.27083333333334),
#  (66, 187.27083333333334),
#  (63, 187.27083333333334),
#  (59, 187.27083333333334),
#  (56, 187.27083333333334),
#  (52, 187.27083333333334),
#  (62, 187.27083333333334),
#  (59, 187.27083333333334),
#  (56, 187.27083333333334),
#  (52, 187.27083333333334),
#  (58, 187.28541666666666),
#  (75, 187.28541666666666),
#  (94, 187.30625),
#  (34, 187.30625),
#  (104, 187.32083333333333),
#  (29, 187.32083333333333),
#  (101, 187.34166666666667),
#  (104, 187.35625),
#  (29, 187.35625),
# ...

# %%
mini = 999999999
for k in L:
    if len(k) < 2:
        continue
    if mini > int(k[1]) and int(k[1]) >=119999:
        mini = int(k[1])
mini
# Out:
# 122040
