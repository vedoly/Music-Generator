# %%
from midiutil.MidiFile import MIDIFile
mid = MidiFile('data/Canon_for_Brass_Quintet_Ver._2.mid') 

mid.
# Out:
# <midi file 'data/Canon_for_Brass_Quintet_Ver._2.mid' type 1, 5 tracks, 4223 messages>

# %%
# Out:
# [[0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 33, 0],
#  [0, 37, 0],
#  [0, 37, 0],
#  [0, 37, 0],
#  [0, 37, 0],
#  [0, 37, 0],
#  [0, 37, 0],
#  [0, 37, 0],
#  [0, 37, 0],
#  [0, 37, 0],
#  [0, 37, 0],
#  [0, 37, 0],
#  [0, 37, 0],
#  [0, 37, 0],
#  [0, 37, 0],
#  [0, 37, 0],
#  [0, 37, 0],
# ...
